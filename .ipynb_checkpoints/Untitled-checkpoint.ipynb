# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# /workspace

# %%
df=pd.read_csv("warehouse.csv")

# %%
import pandas as pd
from deltalake import write_deltalake
import os

def ingest_to_delta():
    # 1. Configuración de credenciales (extraídas de tu código original)
    s3_endpoint = os.getenv("S3_ENDPOINT", "http://minio:9000")
    access_key = os.getenv("AWS_ACCESS_KEY_ID", "admin")
    secret_key = os.getenv("AWS_SECRET_ACCESS_KEY", "password123")
    region = os.getenv("AWS_REGION", "us-east-1")
    
    print(f"Iniciando configuración hacia {s3_endpoint}...")

    # 2. Diccionario de configuración para MinIO/S3
    # La configuración "AWS_S3_ALLOW_UNSAFE_RENAME" es importante cuando se usa MinIO 
    # u otros sistemas de almacenamiento compatibles con S3 que no bloquean archivos.
    storage_options = {
        "AWS_ENDPOINT_URL": s3_endpoint,
        "AWS_ACCESS_KEY_ID": access_key,
        "AWS_SECRET_ACCESS_KEY": secret_key,
        "AWS_REGION": region,
        "AWS_S3_ALLOW_UNSAFE_RENAME": "true" ,
        "AWS_ALLOW_HTTP": "true"  # <--- Agrega esta línea
    }

    # 3. Leer el DataFrame desde tu archivo CSV
    print("Cargando el archivo warehouse.csv...")
    try:
        df = pd.read_csv("warehouse.csv")
    except FileNotFoundError:
        print("Error: No se encontró el archivo 'warehouse.csv'.")
        return

    # 4. Escribir a Delta Lake en el bucket 'retail'
    # Define la ruta destino (puedes cambiar 'warehouse_data' por la carpeta que prefieras)
    delta_path = "s3://retail/warehouse_data"
    
    print(f"Escribiendo DataFrame a formato Delta Lake en la ruta: {delta_path}...")
    
    write_deltalake(
        delta_path,
        df,
        storage_options=storage_options,
        mode="overwrite" # Usa "append" si vas a agregar datos sobre una tabla existente
    )
    
    print("¡Ingesta a Delta Lake completada con éxito!")

if __name__ == "__main__":
    ingest_to_delta()
# Out:
# Iniciando configuración hacia http://minio:9000...
# Cargando el archivo warehouse.csv...
# Escribiendo DataFrame a formato Delta Lake en la ruta: s3://retail/warehouse_data...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 49
#      46     print("¡Ingesta a Delta Lake completada con éxito!")
#      48 if __name__ == "__main__":
# ---> 49     ingest_to_delta()
#
# Cell In[7], line 39, in ingest_to_delta()
#      35 delta_path = "s3://retail/warehouse_data"
#      37 print(f"Escribiendo DataFrame a formato Delta Lake en la ruta: {delta_path}...")
# ---> 39 write_deltalake(
#      40     delta_path,
#      41     df,
#      42     storage_options=storage_options,
#      43     mode="overwrite" # Usa "append" si vas a agregar datos sobre una tabla existente
#      44 )
#      46 print("¡Ingesta a Delta Lake completada con éxito!")
#
# File /usr/local/lib/python3.10/site-packages/deltalake/writer.py:261, in write_deltalake(table_or_uri, data, schema, partition_by, mode, file_options, max_partitions, max_open_files, max_rows_per_file, min_rows_per_group, max_rows_per_group, name, description, configuration, overwrite_schema, schema_mode, storage_options, partition_filters, predicate, large_dtypes, engine, writer_properties, custom_metadata)
#     172 def write_deltalake(
#     173     table_or_uri: Union[str, Path, DeltaTable],
#     174     data: Union[
#    (...)
#     203     custom_metadata: Optional[Dict[str, str]] = None,
#     204 ) -> None:
#     205     """Write to a Delta Lake table
#     206
#     207     If the table does not already exist, it will be created.
#    (...)
#     259         custom_metadata: Custom metadata to add to the commitInfo.
#     260     """
# --> 261     table, table_uri = try_get_table_and_table_uri(table_or_uri, storage_options)
#     262     if table is not None:
#     263         storage_options = table._storage_options or {}
#
# File /usr/local/lib/python3.10/site-packages/deltalake/writer.py:667, in try_get_table_and_table_uri(table_or_uri, storage_options)
#     664     raise ValueError("table_or_uri must be a str, Path or DeltaTable")
#     666 if isinstance(table_or_uri, (str, Path)):
# --> 667     table = try_get_deltatable(table_or_uri, storage_options)
#     668     table_uri = str(table_or_uri)
#     669 else:
#
# File /usr/local/lib/python3.10/site-packages/deltalake/writer.py:680, in try_get_deltatable(table_uri, storage_options)
#     676 def try_get_deltatable(
#     677     table_uri: Union[str, Path], storage_options: Optional[Dict[str, str]]
#     678 ) -> Optional[DeltaTable]:
#     679     try:
# --> 680         return DeltaTable(table_uri, storage_options=storage_options)
#     681     except TableNotFoundError:
#     682         return None
#
# File /usr/local/lib/python3.10/site-packages/deltalake/table.py:408, in DeltaTable.__init__(self, table_uri, version, storage_options, without_files, log_buffer_size)
#     388 """
#     389 Create the Delta Table from a path with an optional version.
#     390 Multiple StorageBackends are currently supported: AWS S3, Azure Data Lake Storage Gen2, Google Cloud Storage (GCS) and local URI.
#    (...)
#     405
#     406 """
#     407 self._storage_options = storage_options
# --> 408 self._table = RawDeltaTable(
#     409     str(table_uri),
#     410     version=version,
#     411     storage_options=storage_options,
#     412     without_files=without_files,
#     413     log_buffer_size=log_buffer_size,
#     414 )
#
# OSError: Generic S3 error: Error after 0 retries in 113.464µs, max_retries:10, retry_timeout:180s, source:builder error for url (http://minio:9000/retail/warehouse_data/_delta_log/_last_checkpoint): URL scheme is not allowed
